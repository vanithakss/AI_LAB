# %%
#Simulated Annealing to solve N Queens problem
import random
import math

def generateRandomBoard(n):
    """Generate a random board represented by a permutation of columns."""
    return random.sample(range(n), n)

def generateNeighbor(state):
    """Generate a neighbor by moving one queen to another row in its column."""
    newState = state[:]
    row = random.randint(0, len(state) - 1)
    newRow = random.randint(0, len(state) - 1)

    # Ensure the queen moves to a different row (no self-move)
    while newRow == newState[row]:
        newRow = random.randint(0, len(state) - 1)

    newState[row] = newRow
    return newState

def calculateEnergy(state):
    """Calculate the number of attacking pairs of queens."""
    conflicts = 0
    n = len(state)

    for i in range(n):
        for j in range(i + 1, n):
            if state[i] == state[j]:  # Same column
                conflicts += 1
            if abs(state[i] - state[j]) == abs(i - j):  # Same diagonal
                conflicts += 1
    return conflicts

def simulatedAnnealing(n, initialTemperature=1000, minimumTemperature=0.01, alpha=0.95, numberOfIterations=100):
    """Simulated Annealing algorithm to solve the N-Queens problem."""
    # Generate an initial random board
    currentState = generateRandomBoard(n)
    currentEnergy = calculateEnergy(currentState)
    T = initialTemperature

    print("Starting simulated annealing...")

    # Iterate while the temperature is above the minimum
    iteration = 0
    while T > minimumTemperature:
        iteration += 1
        print(f"\nIteration {iteration}, Temperature: {T:.4f}")
        print(f"Current state: {currentState}")
        print(f"Current energy (conflicts): {currentEnergy}")

        for _ in range(numberOfIterations):
            # Generate a random neighbor (new board configuration)
            nextState = generateNeighbor(currentState)
            nextEnergy = calculateEnergy(nextState)

            # If the next state is better or accepted by probability
            if nextEnergy < currentEnergy:
                currentState = nextState
                currentEnergy = nextEnergy
            else:
                deltaEnergy = nextEnergy - currentEnergy
                probability = math.exp(-deltaEnergy / T)
                if random.random() < probability:
                    currentState = nextState
                    currentEnergy = nextEnergy

        # Cool the temperature
        T *= alpha

        # If a solution with zero conflicts is found, return the solution
        if currentEnergy == 0:
            return currentState

    # Return the best state found if no perfect solution is found
    return currentState

# Function to handle user input for the board configuration
def getUserInput(n):
    """Get user input for the initial configuration of queens."""
    while True:
        try:
            # Ask the user for the queen positions
            user_input = input(f"Enter the initial positions of the queens (0 to {n-1} for {n} queens, separated by spaces): ")
            positions = list(map(int, user_input.split()))

            # Validate the input
            if len(positions) != n:
                print(f"Error: You must provide exactly {n} positions.")
                continue

            # Ensure no duplicates (no two queens in the same column)
            if len(set(positions)) != n:
                print("Error: Two queens cannot be placed in the same column.")
                continue

            # Ensure the positions are within the valid range (0 to n-1)
            if any(pos < 0 or pos >= n for pos in positions):
                print(f"Error: Queen positions must be between 0 and {n-1}.")
                continue

            return positions
        except ValueError:
            print("Error: Invalid input. Please enter integers separated by spaces.")


# Main function to get user input and run the algorithm
if __name__ == "__main__":
    n = int(input("Enter the number of queens (n): "))

    # Get user input for the initial positions of the queens
    initial_state = getUserInput(n)

    # Calculate energy for the initial state
    initial_energy = calculateEnergy(initial_state)
    print(f"Initial board configuration: {initial_state}")
    print(f"Initial energy (conflicts): {initial_energy}")

    # Run the simulated annealing algorithm
    solution = simulatedAnnealing(n)

    # Output the results
    if calculateEnergy(solution) == 0:
        print("\nSolution found!")
        print(solution)
    else:
        print("\nNo perfect solution found. Best found solution:")
        print(solution)

print("Vanitha - 1BM22CS317")
# Out:
# Enter the number of queens (n): 4
# Enter the initial positions of the queens (0 to 3 for 4 queens, separated by spaces): 3 2 1 0
# Initial board configuration: [3, 2, 1, 0]
# Initial energy (conflicts): 6
# Starting simulated annealing...
#
# Iteration 1, Temperature: 1000.0000
# Current state: [2, 0, 1, 3]
# Current energy (conflicts): 1
#
# Iteration 2, Temperature: 950.0000
# Current state: [0, 1, 0, 1]
# Current energy (conflicts): 5
#
# Iteration 3, Temperature: 902.5000
# Current state: [2, 2, 3, 0]
# Current energy (conflicts): 3
#
# Iteration 4, Temperature: 857.3750
# Current state: [1, 0, 1, 0]
# Current energy (conflicts): 5
#
# Iteration 5, Temperature: 814.5062
# Current state: [3, 2, 0, 1]
# Current energy (conflicts): 2
#
# Iteration 6, Temperature: 773.7809
# Current state: [1, 0, 3, 1]
# Current energy (conflicts): 3
#
# Iteration 7, Temperature: 735.0919
# Current state: [1, 1, 3, 2]
# Current energy (conflicts): 3
#
# Iteration 8, Temperature: 698.3373
# Current state: [3, 3, 1, 1]
# Current energy (conflicts): 4
#
# Iteration 9, Temperature: 663.4204
# Current state: [0, 1, 3, 1]
# Current energy (conflicts): 2
#
# Iteration 10, Temperature: 630.2494
# Current state: [1, 1, 1, 3]
# Current energy (conflicts): 4
#
# Iteration 11, Temperature: 598.7369
# Current state: [2, 2, 3, 2]
# Current energy (conflicts): 5
#
# Iteration 12, Temperature: 568.8001
# Current state: [1, 1, 2, 1]
# Current energy (conflicts): 5
#
# Iteration 13, Temperature: 540.3601
# Current state: [3, 3, 3, 2]
# Current energy (conflicts): 4
#
# Iteration 14, Temperature: 513.3421
# Current state: [2, 0, 1, 2]
# Current energy (conflicts): 4
#
# Iteration 15, Temperature: 487.6750
# Current state: [3, 3, 2, 3]
# Current energy (conflicts): 5
#
# Iteration 16, Temperature: 463.2912
# Current state: [3, 3, 1, 1]
# Current energy (conflicts): 4
#
# Iteration 17, Temperature: 440.1267
# Current state: [1, 0, 0, 2]
# Current energy (conflicts): 3
#
# Iteration 18, Temperature: 418.1203
# Current state: [0, 2, 1, 0]
# Current energy (conflicts): 4
#
# Iteration 19, Temperature: 397.2143
# Current state: [2, 3, 2, 0]
# Current energy (conflicts): 3
#
# Iteration 20, Temperature: 377.3536
# Current state: [0, 2, 2, 3]
# Current energy (conflicts): 4
#
# Iteration 21, Temperature: 358.4859
# Current state: [2, 2, 2, 0]
# Current energy (conflicts): 4
#
# Iteration 22, Temperature: 340.5616
# Current state: [0, 0, 0, 3]
# Current energy (conflicts): 4
#
# Iteration 23, Temperature: 323.5335
# Current state: [3, 1, 0, 2]
# Current energy (conflicts): 1
#
# Iteration 24, Temperature: 307.3569
# Current state: [0, 0, 2, 2]
# Current energy (conflicts): 4
#
# Iteration 25, Temperature: 291.9890
# Current state: [1, 1, 2, 0]
# Current energy (conflicts): 2
#
# Iteration 26, Temperature: 277.3896
# Current state: [2, 1, 0, 2]
# Current energy (conflicts): 4
#
# Iteration 27, Temperature: 263.5201
# Current state: [2, 3, 0, 2]
# Current energy (conflicts): 3
#
# Iteration 28, Temperature: 250.3441
# Current state: [2, 3, 2, 3]
# Current energy (conflicts): 5
#
# Iteration 29, Temperature: 237.8269
# Current state: [0, 2, 1, 2]
# Current energy (conflicts): 3
#
# Iteration 30, Temperature: 225.9355
# Current state: [0, 3, 2, 0]
# Current energy (conflicts): 3
#
# Iteration 31, Temperature: 214.6388
# Current state: [3, 2, 1, 3]
# Current energy (conflicts): 4
#
# Iteration 32, Temperature: 203.9068
# Current state: [2, 3, 0, 3]
# Current energy (conflicts): 3
#
# Iteration 33, Temperature: 193.7115
# Current state: [2, 3, 0, 0]
# Current energy (conflicts): 3
#
# Iteration 34, Temperature: 184.0259
# Current state: [1, 1, 2, 2]
# Current energy (conflicts): 3
#
# Iteration 35, Temperature: 174.8246
# Current state: [2, 0, 3, 0]
# Current energy (conflicts): 1
#
# Iteration 36, Temperature: 166.0834
# Current state: [3, 0, 2, 0]
# Current energy (conflicts): 2
#
# Iteration 37, Temperature: 157.7792
# Current state: [3, 1, 0, 0]
# Current energy (conflicts): 3
#
# Iteration 38, Temperature: 149.8903
# Current state: [2, 3, 1, 2]
# Current energy (conflicts): 3
#
# Iteration 39, Temperature: 142.3957
# Current state: [2, 2, 0, 0]
# Current energy (conflicts): 4
#
# Iteration 40, Temperature: 135.2760
# Current state: [3, 0, 2, 3]
# Current energy (conflicts): 2
#
# Iteration 41, Temperature: 128.5122
# Current state: [1, 3, 1, 0]
# Current energy (conflicts): 2
#
# Iteration 42, Temperature: 122.0865
# Current state: [1, 0, 3, 3]
# Current energy (conflicts): 3
#
# Iteration 43, Temperature: 115.9822
# Current state: [0, 1, 2, 2]
# Current energy (conflicts): 4
#
# Iteration 44, Temperature: 110.1831
# Current state: [0, 2, 0, 2]
# Current energy (conflicts): 2
#
# Iteration 45, Temperature: 104.6740
# Current state: [0, 0, 2, 3]
# Current energy (conflicts): 4
#
# Iteration 46, Temperature: 99.4403
# Current state: [0, 3, 1, 2]
# Current energy (conflicts): 1
#
# Iteration 47, Temperature: 94.4682
# Current state: [3, 1, 2, 1]
# Current energy (conflicts): 3
#
# Iteration 48, Temperature: 89.7448
# Current state: [0, 0, 3, 3]
# Current energy (conflicts): 3
#
# Iteration 49, Temperature: 85.2576
# Current state: [3, 3, 0, 1]
# Current energy (conflicts): 3
#
# Iteration 50, Temperature: 80.9947
# Current state: [0, 1, 0, 1]
# Current energy (conflicts): 5
#
# Iteration 51, Temperature: 76.9450
# Current state: [2, 2, 2, 2]
# Current energy (conflicts): 6
#
# Iteration 52, Temperature: 73.0977
# Current state: [1, 0, 0, 0]
# Current energy (conflicts): 4
#
# Iteration 53, Temperature: 69.4428
# Current state: [3, 0, 0, 3]
# Current energy (conflicts): 2
#
# Iteration 54, Temperature: 65.9707
# Current state: [3, 0, 2, 1]
# Current energy (conflicts): 1
#
# Iteration 55, Temperature: 62.6722
# Current state: [0, 3, 2, 0]
# Current energy (conflicts): 3
#
# Iteration 56, Temperature: 59.5386
# Current state: [0, 2, 1, 0]
# Current energy (conflicts): 4
#
# Iteration 57, Temperature: 56.5616
# Current state: [2, 1, 0, 0]
# Current energy (conflicts): 4
#
# Iteration 58, Temperature: 53.7335
# Current state: [3, 3, 1, 1]
# Current energy (conflicts): 4
#
# Iteration 59, Temperature: 51.0469
# Current state: [0, 3, 3, 0]
# Current energy (conflicts): 2
#
# Iteration 60, Temperature: 48.4945
# Current state: [0, 0, 0, 2]
# Current energy (conflicts): 4
#
# Iteration 61, Temperature: 46.0698
# Current state: [2, 1, 0, 2]
# Current energy (conflicts): 4
#
# Iteration 62, Temperature: 43.7663
# Current state: [3, 2, 2, 1]
# Current energy (conflicts): 3
#
# Iteration 63, Temperature: 41.5780
# Current state: [2, 3, 1, 2]
# Current energy (conflicts): 3
#
# Iteration 64, Temperature: 39.4991
# Current state: [3, 2, 0, 3]
# Current energy (conflicts): 2
#
# Iteration 65, Temperature: 37.5241
# Current state: [1, 1, 1, 2]
# Current energy (conflicts): 4
#
# Iteration 66, Temperature: 35.6479
# Current state: [1, 3, 3, 3]
# Current energy (conflicts): 4
#
# Iteration 67, Temperature: 33.8655
# Current state: [3, 0, 0, 3]
# Current energy (conflicts): 2
#
# Iteration 68, Temperature: 32.1723
# Current state: [1, 2, 2, 1]
# Current energy (conflicts): 4
#
# Iteration 69, Temperature: 30.5636
# Current state: [3, 1, 3, 3]
# Current energy (conflicts): 4
#
# Iteration 70, Temperature: 29.0355
# Current state: [0, 0, 3, 0]
# Current energy (conflicts): 3
#
# Iteration 71, Temperature: 27.5837
# Current state: [3, 3, 0, 1]
# Current energy (conflicts): 3
#
# Iteration 72, Temperature: 26.2045
# Current state: [3, 3, 2, 0]
# Current energy (conflicts): 3
#
# Iteration 73, Temperature: 24.8943
# Current state: [1, 0, 1, 0]
# Current energy (conflicts): 5
#
# Iteration 74, Temperature: 23.6496
# Current state: [2, 1, 0, 1]
# Current energy (conflicts): 5
#
# Iteration 75, Temperature: 22.4671
# Current state: [2, 0, 2, 0]
# Current energy (conflicts): 2
#
# Iteration 76, Temperature: 21.3437
# Current state: [0, 1, 3, 1]
# Current energy (conflicts): 2
#
# Iteration 77, Temperature: 20.2765
# Current state: [1, 1, 2, 0]
# Current energy (conflicts): 2
#
# Iteration 78, Temperature: 19.2627
# Current state: [1, 3, 1, 2]
# Current energy (conflicts): 2
#
# Iteration 79, Temperature: 18.2996
# Current state: [3, 0, 1, 1]
# Current energy (conflicts): 3
#
# Iteration 80, Temperature: 17.3846
# Current state: [1, 0, 2, 3]
# Current energy (conflicts): 2
#
# Iteration 81, Temperature: 16.5154
# Current state: [0, 0, 2, 2]
# Current energy (conflicts): 4
#
# Iteration 82, Temperature: 15.6896
# Current state: [3, 3, 0, 2]
# Current energy (conflicts): 1
#
# Iteration 83, Temperature: 14.9051
# Current state: [2, 1, 0, 2]
# Current energy (conflicts): 4
#
# Iteration 84, Temperature: 14.1599
# Current state: [1, 0, 2, 3]
# Current energy (conflicts): 2
#
# Iteration 85, Temperature: 13.4519
# Current state: [2, 1, 3, 2]
# Current energy (conflicts): 3
#
# Iteration 86, Temperature: 12.7793
# Current state: [3, 1, 1, 2]
# Current energy (conflicts): 3
#
# Iteration 87, Temperature: 12.1403
# Current state: [3, 1, 3, 0]
# Current energy (conflicts): 2
#
# Iteration 88, Temperature: 11.5333
# Current state: [2, 3, 0, 1]
# Current energy (conflicts): 4
#
# Iteration 89, Temperature: 10.9566
# Current state: [1, 2, 1, 0]
# Current energy (conflicts): 5
#
# Iteration 90, Temperature: 10.4088
# Current state: [2, 0, 0, 2]
# Current energy (conflicts): 4
#
# Iteration 91, Temperature: 9.8884
# Current state: [0, 0, 1, 0]
# Current energy (conflicts): 5
#
# Iteration 92, Temperature: 9.3939
# Current state: [2, 3, 1, 2]
# Current energy (conflicts): 3
#
# Iteration 93, Temperature: 8.9242
# Current state: [0, 0, 2, 1]
# Current energy (conflicts): 3
#
# Iteration 94, Temperature: 8.4780
# Current state: [2, 3, 2, 3]
# Current energy (conflicts): 5
#
# Iteration 95, Temperature: 8.0541
# Current state: [0, 2, 1, 0]
# Current energy (conflicts): 4
#
# Iteration 96, Temperature: 7.6514
# Current state: [3, 0, 2, 2]
# Current energy (conflicts): 2
#
# Iteration 97, Temperature: 7.2689
# Current state: [1, 2, 1, 0]
# Current energy (conflicts): 5
#
# Iteration 98, Temperature: 6.9054
# Current state: [1, 2, 0, 0]
# Current energy (conflicts): 3
#
# Iteration 99, Temperature: 6.5601
# Current state: [2, 0, 2, 0]
# Current energy (conflicts): 2
#
# Iteration 100, Temperature: 6.2321
# Current state: [2, 2, 3, 0]
# Current energy (conflicts): 3
#
# Iteration 101, Temperature: 5.9205
# Current state: [3, 0, 1, 1]
# Current energy (conflicts): 3
#
# Iteration 102, Temperature: 5.6245
# Current state: [1, 3, 1, 3]
# Current energy (conflicts): 2
#
# Iteration 103, Temperature: 5.3433
# Current state: [3, 0, 3, 1]
# Current energy (conflicts): 1
#
# Iteration 104, Temperature: 5.0761
# Current state: [1, 2, 1, 2]
# Current energy (conflicts): 5
#
# Iteration 105, Temperature: 4.8223
# Current state: [0, 1, 0, 1]
# Current energy (conflicts): 5
#
# Iteration 106, Temperature: 4.5812
# Current state: [3, 3, 1, 2]
# Current energy (conflicts): 3
#
# Iteration 107, Temperature: 4.3521
# Current state: [1, 3, 0, 3]
# Current energy (conflicts): 1
#
# Iteration 108, Temperature: 4.1345
# Current state: [0, 3, 0, 0]
# Current energy (conflicts): 3
#
# Solution found!
# [2, 0, 3, 1]
# Vanitha - 1BM22CS317
